# %% [markdown]
# # Elcom Netzbetreibertarife abrufen via Linked Data Services LINDAS
#
# Die Linked Data Services Platform des Bundes, kurz LINDAS, erlaubt es, mittels der query-sprache SPARQL Daten abzufragen. Daten aus unterschiedlichen Datenbanken können ohne expliziten JOIN kombiniert und verbunden werden.
#
# Das nachfolgende Jupyter-Notebook bietet einen kleinen Überblick und code snippets zur Durchführung einfacher abfragen.
#
# Dieses Notebook könnte man als leich abgeänderte und verkürzte Versions des Notebooks der Firma Zazuko betrachten, welche unter folgendem Link auffindbar ist: [Link zum Zazuko Notebook](https://jupyter.zazuko.com/electricity_prices.html).

# %% [markdown]
# ### Packages installieren
# Um die LINDAS Datenbank via Python zu erreichen, bedarf es folgenden Python Packages
# * Pandas (für die Datenverarbeitung)
# * SparqlClient von graphly (um SPARQL abfragen zu schreiben)
#
# Der SparqlClient ist auf GitHub zu finden (https://github.com/zazuko/graphly) und kann mittels folgendem commmand im terminal installiert werden: `pip install git+https://github.com/zazuko/graphly`

# %%
# !pip install pandas
# !pip install git+https://github.com/zazuko/graphly.git
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting git+https://github.com/zazuko/graphly.git
#   Cloning https://github.com/zazuko/graphly.git to /private/var/folders/x5/3_ztps2d5gn3l472r72dmmn80000gn/T/pip-req-build-4mq1s4jl
#   Running command git clone --filter=blob:none --quiet https://github.com/zazuko/graphly.git /private/var/folders/x5/3_ztps2d5gn3l472r72dmmn80000gn/T/pip-req-build-4mq1s4jl
#   Resolved https://github.com/zazuko/graphly.git to commit 4e7ca9987ab08f6e11ced977e003c244832ef42b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.25.1 in /opt/anaconda3/lib/python3.12/site-packages (from graphly==0.1) (2.32.3)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from graphly==0.1) (3.3)
# Requirement already satisfied: matplotlib>=3.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from graphly==0.1) (3.9.2)
# Collecting geopandas>=0.9.0 (from graphly==0.1)
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pandas>=1.2.4 in /opt/anaconda3/lib/python3.12/site-packages (from graphly==0.1) (2.2.2)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/lib/python3.12/site-packages (from geopandas>=0.9.0->graphly==0.1) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas>=0.9.0->graphly==0.1)
#   Downloading pyogrio-0.11.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from geopandas>=0.9.0->graphly==0.1) (24.1)
# Collecting pyproj>=3.5.0 (from geopandas>=0.9.0->graphly==0.1)
#   Downloading pyproj-3.7.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas>=0.9.0->graphly==0.1)
#   Downloading shapely-2.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (1.4.4)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.1->graphly==0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2.4->graphly==0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2.4->graphly==0.1) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.1->graphly==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.1->graphly==0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.1->graphly==0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.1->graphly==0.1) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.4.1->graphly==0.1) (1.16.0)
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.11.1-cp312-cp312-macosx_12_0_arm64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 15.5 MB/s eta 0:00:0000:0100:01
# Downloading pyproj-3.7.1-cp312-cp312-macosx_14_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 16.1 MB/s eta 0:00:00a 0:00:01
# Downloading shapely-2.1.1-cp312-cp312-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.1 MB/s eta 0:00:00
# Building wheels for collected packages: graphly
#   Building wheel for graphly (setup.py) ... done
#   Created wheel for graphly: filename=graphly-0.1-py3-none-any.whl size=5206 sha256=3c3db0d67bf7f7b960d2650202b10b9343c276114795a22f9e9c8ea0d828bead
#   Stored in directory: /private/var/folders/x5/3_ztps2d5gn3l472r72dmmn80000gn/T/pip-ephem-wheel-cache-dxylh604/wheels/a4/d3/ab/7ea4d6c4755bb0610ab0459a82fdbca8deb96a33eda2b73566
# Successfully built graphly
# Installing collected packages: shapely, pyproj, pyogrio, geopandas, graphly
# Successfully installed geopandas-1.1.1 graphly-0.1 pyogrio-0.11.1 pyproj-3.7.1 shapely-2.1.1

# %% [markdown]
# Nach erfolgreicher installation können die Packages importiert werden:

# %%
import pandas as pd
from graphly.api_client import SparqlClient

# %% [markdown]
# LINDAS entspricht der RDF-Architektur, wobei RDF für Resource Description Framework steht. Für die SPARQL Abfrage werden tripels bestehend aus Subjekt, Prädikat und Objekt deklariert, die dieses Muster in der verlinkten Datenstruktur angleichen. Einen guten Einstieg in linked data und SPARQL bietet das folgende video: https://www.youtube.com/watch?v=FvGndkpa4K0
#
# Im folgenden werden ein paar queries aufgezeigt, die in Zukunft hilfreich sein könnten. Als erstes muss eine Sparql-Client Instanz mit einem endpoint definiert werden, um die Abfragen durchzuführen zu können.

# %%
sparql = SparqlClient("https://lindas.admin.ch/query")
geosparql = SparqlClient("https://geo.ld.admin.ch/query")

sparql.add_prefixes({
    "schema": "<http://schema.org/>",
    "cube": "<https://cube.link/>",
    "elcom": "<https://energy.ld.admin.ch/elcom/electricityprice/dimension/>",
    "admin": "<https://schema.ld.admin.ch/>"
})

geosparql.add_prefixes({
    "dct": "<http://purl.org/dc/terms/>",
    "geonames": "<http://www.geonames.org/ontology#>",
    "schema": "<http://schema.org/>",
    "geosparql": "<http://www.opengis.net/ont/geosparql#>",
})

# %% [markdown]
# ### Liste aller Netzbetreiber
# Im Folgenden eine vollständige Liste aller Netzbetreiber gemässe elcom. Unter dem folgenden [Link](https://s.zazuko.com/wE57VK) kann die Abfrage direkt als SPARQL auf der LINDAS-homepage durchgeführt werden.

# %%
query1 = f"""
  SELECT DISTINCT ?operatorName
  FROM <https://lindas.admin.ch/elcom/electricityprice>
  WHERE {{

    <https://energy.ld.admin.ch/elcom/electricityprice> cube:observationSet/cube:observation ?obs .

    # ?obs a cube:Observation ;
      elcom:period "2025"^^xsd:gYear ; # data available up to 10 years ago
      # elcom:municipality ?muniri ;
      elcom:category/schema:name ?category;
      elcom:operator ?operator .

    # ?operator schema:name ?operatorName .

    FILTER( ?category = "C3")

  }}
  """
operatorNames = pd.DataFrame()
operatorNames = sparql.send_query(query1)
operatorNames.head()
# Out:
#                                        operatorName
# 0       Elektrizitätswerke des Kantons Zürich (EKZ)
# 1             Gemeinde Andelfingen, Stromversorgung
# 2             Elektrizitätsgenossenschaft Marthalen
# 3      Politische Gemeinde Dietlikon, Gemeindewerke
# 4  Genossenschaft Licht- und Kraftwerke Glattfelden

# %% [markdown]
# ### Liste aller Gemeinden und ihre jeweiligen Netzbetreiber
# Im Folgenden eine Abfrage der jeweiligen Gemeinden und entsprechende Netzbetreiber. Unter dem folgenden [Link](https://s.zazuko.com/ZEvzwf) kann die Abfrage direkt als SPARQL auf der LINDAS-homepage durchgeführt werden.

# %%
query2 = """
    PREFIX schema: <http://schema.org/>
    PREFIX cube: <https://cube.link/>
    PREFIX elcom: <https://energy.ld.admin.ch/elcom/electricityprice/dimension/>
    PREFIX admin: <https://schema.ld.admin.ch/>

    SELECT ?municipality_id (2025 as ?period) ?operatorName ?category ?energy ?grid ?aidfee (?community_fees + ?aidfee as ?taxes) ?fixcosts ?variablecosts
    FROM <https://lindas.admin.ch/elcom/electricityprice>
    WHERE {
        <https://energy.ld.admin.ch/elcom/electricityprice/observation/> cube:observation ?observation.

        # ?observation
        elcom:category/schema:name ?category;
        elcom:municipality ?municipality_id;
        elcom:period "2025"^^<http://www.w3.org/2001/XMLSchema#gYear>;
        elcom:product <https://energy.ld.admin.ch/elcom/electricityprice/product/standard>;
        elcom:fixcosts ?fixcosts;
        elcom:total ?variablecosts;
        elcom:operator ?operator ;
        elcom:gridusage ?grid;
        elcom:energy ?energy;
        elcom:charge ?community_fees;
        elcom:aidfee ?aidfee.

        # Fetch operator information
        # ?operator schema:name ?operatorName .

        # Filter for Zürich (assuming Bern has a known municipality_id)
        FILTER (?municipality_id = <https://ld.admin.ch/municipality/191>)  # Replace with the actual URI for Bern
    }
    ORDER BY ?municipality_id ?category ?variablecosts
    LIMIT 20
  """
operatorNames = pd.DataFrame()
operatorNames = sparql.send_query(query2)
operatorNames.head(20)
# Out:
#                          municipality_id  period  operatorName category  \
# 0   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C1
# 1   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C2
# 2   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C3
# 3   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C4
# 4   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C5
# 5   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C6
# 6   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       C7
# 7   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H1
# 8   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H2
# 9   https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H3
# 10  https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H4
# 11  https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H5
# 12  https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H6
# 13  https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H7
# 14  https://ld.admin.ch/municipality/191    2025  Glattwerk AG       H8
#
#     energy    grid  aidfee  taxes  fixcosts  variablecosts
# 0   15.321  11.125     2.3    2.3      90.0         28.746
# 1   15.389  10.252     2.3    2.3      90.0         27.941
# 2   14.907   9.704     2.3    2.3     240.0         26.911
# 3   14.835   9.097     2.3    2.3     240.0         26.233
# 4   14.835   6.531     2.3    2.3     360.0         23.667
# 5   14.273   6.114     2.3    2.3     360.0         22.687
# 6   14.172   5.477     2.3    2.3     360.0         21.950
# 7   15.092  14.831     2.3    2.3      90.0         32.223
# 8   15.064  12.755     2.3    2.3      90.0         30.119
# 9   14.771  10.544     2.3    2.3      90.0         27.615
# 10  15.069  11.184     2.3    2.3      90.0         28.553
# 11  14.794   9.830     2.3    2.3      90.0         26.924
# 12  15.077   8.395     2.3    2.3      90.0         25.772
# 13  15.200   9.507     2.3    2.3      90.0         27.007
# 14  15.070  10.384     2.3    2.3      90.0         27.754

# %% [markdown]
# ### Liste alles Addressen
# Im Folgenden eine Abfrage die alle Addressen der Schweiz retourniert, sowie die position als Punkt-Geometrie. Unter dem folgenden [Link](https://s.zazuko.com/BULwVM) kann die Abfrage direkt als SPARQL auf der LINDAS-homepage durchgeführt werden.

# %%
query3 = """
    PREFIX schema: <http://schema.org/>
    PREFIX gn: <http://www.geonames.org/ontology#>
    PREFIX geo: <http://www.opengis.net/ont/geosparql#>
    PREFIX dct: <http://purl.org/dc/terms/>

    SELECT ?address ?street ?locality ?postalCode ?geometry
    WHERE {
    # ?address a schema:PostalAddress ;
           schema:streetAddress ?street ;
           schema:addressLocality ?locality ;
           schema:postalCode ?postalCode ;
           geo:hasGeometry ?geometry .
    }
    LIMIT 100
    """
addresses = pd.DataFrame()
addresses = geosparql.send_query(query3)
addresses.head(20)
# Out:
#                                               address  \
# 0   https://geo.ld.admin.ch/location/address/10190...
# 1   https://geo.ld.admin.ch/location/address/10004...
# 2   https://geo.ld.admin.ch/location/address/10044...
# 3   https://geo.ld.admin.ch/location/address/10004...
# 4   https://geo.ld.admin.ch/location/address/10001...
# 5   https://geo.ld.admin.ch/location/address/10007...
# 6   https://geo.ld.admin.ch/location/address/10004...
# 7   https://geo.ld.admin.ch/location/address/10005...
# 8   https://geo.ld.admin.ch/location/address/10007...
# 9   https://geo.ld.admin.ch/location/address/10007...
# 10  https://geo.ld.admin.ch/location/address/10003...
# 11  https://geo.ld.admin.ch/location/address/10000...
# 12  https://geo.ld.admin.ch/location/address/10044...
# 13  https://geo.ld.admin.ch/location/address/10004...
# 14  https://geo.ld.admin.ch/location/address/10044...
# 15  https://geo.ld.admin.ch/location/address/10000...
# 16  https://geo.ld.admin.ch/location/address/10044...
# 17  https://geo.ld.admin.ch/location/address/10008...
# 18  https://geo.ld.admin.ch/location/address/10004...
# 19  https://geo.ld.admin.ch/location/address/10044...
#
#                               street            locality  \
# 0   Rennweg / Chemin de la Course 47         Biel/Bienne
# 1                       Grossweid 25           Seegräben
# 2                   Tüftelstrasse 53             Koblenz
# 3                    Hertistrasse 19         Gossau (ZH)
# 4                          Leeweg 17              Bülach
# 5                    Dorfstrasse 124              Meilen
# 6                  Schönaustrasse 48           Bäretswil
# 7             Allmendgütlistrasse 19              Horgen
# 8                Wetzikerstrasse 112             Hittnau
# 9                    Huebacherweg 21             Hittnau
# 10              Kellerlochstrasse 9a             Dürnten
# 11             Ottenbacherstrasse 74            Obfelden
# 12                         Rainweg 1      Herznach-Ueken
# 13                   Haldenstrasse 9           Bäretswil
# 14                   Rosenstrasse 11             Zurzach
# 15                Zeughausstrasse 12  Affoltern am Albis
# 16                Meierhofstrasse 32           Unterkulm
# 17                    Thesenacher 41             Zumikon
# 18                Riedmattstrasse 10              Hinwil
# 19                     Fluhgasse 142          Laufenburg
#
#                       postalCode  \
# 0               2504 Biel/Bienne
# 1          8607 Aathal-Seegräben
# 2                   5322 Koblenz
# 3   8614 Bertschikon (Gossau ZH)
# 4                    8180 Bülach
# 5                    8706 Meilen
# 6                 8344 Bäretswil
# 7                    8810 Horgen
# 8                   8335 Hittnau
# 9                   8335 Hittnau
# 10                  8635 Dürnten
# 11                 8912 Obfelden
# 12                    5028 Ueken
# 13                 8345 Adetswil
# 14              5330 Bad Zurzach
# 15       8910 Affoltern am Albis
# 16                5726 Unterkulm
# 17                  8126 Zumikon
# 18            8342 Wernetshausen
# 19               5080 Laufenburg
#
#                                              geometry
# 0   https://geo.ld.admin.ch/location/address/geome...
# 1   https://geo.ld.admin.ch/location/address/geome...
# 2   https://geo.ld.admin.ch/location/address/geome...
# 3   https://geo.ld.admin.ch/location/address/geome...
# 4   https://geo.ld.admin.ch/location/address/geome...
# 5   https://geo.ld.admin.ch/location/address/geome...
# 6   https://geo.ld.admin.ch/location/address/geome...
# 7   https://geo.ld.admin.ch/location/address/geome...
# 8   https://geo.ld.admin.ch/location/address/geome...
# 9   https://geo.ld.admin.ch/location/address/geome...
# 10  https://geo.ld.admin.ch/location/address/geome...
# 11  https://geo.ld.admin.ch/location/address/geome...
# 12  https://geo.ld.admin.ch/location/address/geome...
# 13  https://geo.ld.admin.ch/location/address/geome...
# 14  https://geo.ld.admin.ch/location/address/geome...
# 15  https://geo.ld.admin.ch/location/address/geome...
# 16  https://geo.ld.admin.ch/location/address/geome...
# 17  https://geo.ld.admin.ch/location/address/geome...
# 18  https://geo.ld.admin.ch/location/address/geome...
# 19  https://geo.ld.admin.ch/location/address/geome...

# %% [markdown]
# ### Gemeinde, Netzbetreiber und C3/H4 Tarife
# Im Folgenden die Abfrage nach Gemeinden, Netzbetreiber und Energietarife, gefiltert nach C3 und H4. Unter dem folgenden [Link](https://s.zazuko.com/Uc115h) kann die Abfrage direkt als SPARQL auf der LINDAS-homepage durchgeführt werden.
# Code wurde grosszügig übernommen vom [Zazuko-Notebook](https://jupyter.zazuko.com/electricity_prices.html) mit kleinen Abänderungen.

# %%
query4 = """
    PREFIX schema: <http://schema.org/>
    PREFIX cube: <https://cube.link/>
    PREFIX elcom: <https://energy.ld.admin.ch/elcom/electricityprice/dimension/>
    PREFIX admin: <https://schema.ld.admin.ch/>

    SELECT ?municipality_id ?postal_code (2025 as ?period) ?operatorName ?category ?energy ?grid ?aidfee (?community_fees + ?aidfee as ?taxes) ?fixcosts ?variablecosts
    FROM <https://lindas.admin.ch/elcom/electricityprice>
    WHERE {
    <https://energy.ld.admin.ch/elcom/electricityprice/observation/> cube:observation ?observation.

    # ?observation
      elcom:category/schema:name ?category;
      elcom:municipality ?municipality_id;
      elcom:period "2025"^^<http://www.w3.org/2001/XMLSchema#gYear>;
      elcom:product <https://energy.ld.admin.ch/elcom/electricityprice/product/standard>;
      elcom:fixcosts ?fixcosts;
      elcom:total ?variablecosts;
      elcom:operator ?operator ;
      elcom:gridusage ?grid;
      elcom:energy ?energy;
      elcom:charge ?community_fees;
      elcom:aidfee ?aidfee.

    # Fetch operator information
    # ?operator schema:name ?operatorName .

    # Filter for Bern (assuming Bern has a known municipality_id)
    FILTER (?municipality_id = <https://ld.admin.ch/municipality/1>)  # Replace with the actual URI for Bern
    FILTER( ?category = "C3" || ?category = "H4")
    }
ORDER BY ?municipality_id ?category ?variablecosts
LIMIT 20
  """
operatorNames = pd.DataFrame()
operatorNames = sparql.send_query(query4)
operatorNames.head(20)
# Out:
#                       municipality_id postal_code  period  \
# 0  https://ld.admin.ch/municipality/1        None    2025
# 1  https://ld.admin.ch/municipality/1        None    2025
#
#                                   operatorName category  energy   grid  \
# 0  Elektrizitätswerke des Kantons Zürich (EKZ)       C3  15.312  7.760
# 1  Elektrizitätswerke des Kantons Zürich (EKZ)       H4  15.732  9.313
#
#    aidfee  taxes  fixcosts  variablecosts
# 0     2.3   2.46     720.0         25.532
# 1     2.3   2.46      60.0         27.506
